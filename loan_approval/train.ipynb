# %% [markdown]
# **Loan Approval Model - Random Forest Classifier**

# %% [markdown]
# Internal Working - Trains multiple decision Tree with random subsets of the training dataset

# %% [markdown]
# Classification - It takes the majority voting prediction from all the decision trees hence improving accuracy and reducing overfitting

# %% [markdown]
# Let's import the necessary packages

# %% [markdown]
# Pandas - To load,store,clean and manipulate dataset

# %%
import pandas as pd

# %% [markdown]
# Train test split from model selection - To split the dataset into testing and training dataset to evaluate the model's accuracy finally

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# importing random forest classifier algorithm

# %%
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# Accuracy score from metrics - To check how many predictions are right from the final model

# %%
from sklearn.metrics import accuracy_score

# %% [markdown]
# Confusion matrix and classification report to analyse the overall model's prediction on the test data

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %% [markdown]
# GridSearchCV for finding the best parameters for the random forest classifier model

# %%
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# Numpy for handling numerical computation and array operations

# %%
import numpy as np

# %% [markdown]
# Let's import the dataset

# %%
df = pd.read_csv("dataset/data.csv")

# %% [markdown]
# Display the first 5 rows to ensure that the right dataset has been loaded properly

# %%
df.head()

# %% [markdown]
# X - all the features except the final loan status

# %%
X=df.drop("Loan_Status",axis=1)

# %% [markdown]
# y - final output class [Loan Status]

# %%
y=df["Loan_Status"]

# %% [markdown]
# Let's pre process our X data using one hot encoding

# %%
X=pd.get_dummies(X,drop_first=True)
X.head()
